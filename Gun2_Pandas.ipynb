# %% [markdown]
# # Pandas

# %% [markdown]
# ## Kütüphaneleri Yükleme (Import Libraries)

# %%
# Pandas Kutuphanesi: Veri manipulasyonu
import pandas as pd

# %% [markdown]
# ## Veriyi  Yükleme (Load Data)

# %%
# Pandas seriler oluşturma
#öğrenci adları
names = ["Ameer Abdullah", "Nelson Agholor", "Jay Ajayi", "Kwon Alexander", 
         "Mario Alford", "Javorius Allen", "Adrian Amos", "Dres Anderson", 
         "Henry Anderson", "Rory 'Busta' Anderson"]
names_seri = pd.Series(names)
names_seri
# Out:
# 0           Ameer Abdullah
# 1           Nelson Agholor
# 2                Jay Ajayi
# 3           Kwon Alexander
# 4             Mario Alford
# 5           Javorius Allen
# 6              Adrian Amos
# 7            Dres Anderson
# 8           Henry Anderson
# 9    Rory 'Busta' Anderson
# dtype: object

# %%
points = [205, 198, 221, 227, 180, 221, 
          218, 187, 294, 244]
points_seri = pd.Series(points)
points_seri
# Out:
# 0    205
# 1    198
# 2    221
# 3    227
# 4    180
# 5    221
# 6    218
# 7    187
# 8    294
# 9    244
# dtype: int64

# %%
# iki seriden data frame oluşturma
data = {"names": names_seri, "points": points_seri}
df = pd.DataFrame(data)
df.head()
# Out:
#             names  points
# 0  Ameer Abdullah     205
# 1  Nelson Agholor     198
# 2       Jay Ajayi     221
# 3  Kwon Alexander     227
# 4    Mario Alford     180

# %%
df.columns # sütun isimleri
# Out:
# Index(['names', 'points'], dtype='object')

# %%
df.columns = ["isim", "puan"] # sütun iismlerini değiştir
df
# Out:
#                     isim  puan
# 0         Ameer Abdullah   205
# 1         Nelson Agholor   198
# 2              Jay Ajayi   221
# 3         Kwon Alexander   227
# 4           Mario Alford   180
# 5         Javorius Allen   221
# 6            Adrian Amos   218
# 7          Dres Anderson   187
# 8         Henry Anderson   294
# 9  Rory 'Busta' Anderson   244

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4821-D018
#
#  Directory of C:\Users\emura\Documents\BTK24Nisan\GUN2
#
# 28.04.2024  10:22    <DIR>          .
# 28.04.2024  10:04    <DIR>          ..
# 28.04.2024  10:12    <DIR>          .ipynb_checkpoints
# 28.04.2024  10:10           732.191 combine.csv
# 28.04.2024  10:22             1.522 Gun2_Veri_G”rselleŸtirme.ipynb
#                2 File(s)        733.713 bytes
#                3 Dir(s)  14.932.832.256 bytes free

# %%
#csvdosyasını okuma
df = pd.read_csv("combine.csv")

# %% [markdown]
# ## Keşifsel Veri Analizi EDA (Exploratory Data Analysis)

# %%
df.head() # ilk 5 satırı gösterir metot
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# 0           9.0               69.0     205   0.0  ...      42.5    130     24
# 1           0.0               72.0     198   0.0  ...       0.0      0     12
# 2           0.0               72.0     221   0.0  ...      39.0    121     19
# 3           1.0               73.0     227   0.0  ...      36.0    121     24
# 4           8.0               68.0     180   0.0  ...      34.0    121     13
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# ...

# %%
df.shape #satır ve sütun saılarını verir df nesnesinin özeiiği
# Out:
# (4947, 26)

# %%
df.head(10)
# Out:
#    year                   name     firstname   lastname position  heightfeet  \
# 0  2015         Ameer Abdullah         Ameer   Abdullah       RB           5
# 1  2015         Nelson Agholor        Nelson    Agholor       WR           6
# 2  2015              Jay Ajayi           Jay      Ajayi       RB           6
# 3  2015         Kwon Alexander          Kwon  Alexander      OLB           6
# 4  2015           Mario Alford         Mario     Alford       WR           5
# 5  2015         Javorius Allen      Javorius      Allen       RB           6
# 6  2015            Adrian Amos        Adrian       Amos       FS           6
# 7  2015          Dres Anderson          Dres   Anderson       WR           6
# 8  2015         Henry Anderson         Henry   Anderson       DE           6
# 9  2015  Rory 'Busta' Anderson  Rory 'Busta'   Anderson       TE           6
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4947 entries, 0 to 4946
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               4947 non-null   int64
#  1   name               4947 non-null   object
#  2   firstname          4947 non-null   object
#  3   lastname           4947 non-null   object
#  4   position           4947 non-null   object
#  5   heightfeet         4947 non-null   int64
#  6   heightinches       4947 non-null   float64
#  7   heightinchestotal  4947 non-null   float64
#  8   weight             4947 non-null   int64
#  9   arms               4947 non-null   float64
#  10  hands              4947 non-null   float64
#  11  fortyyd            4947 non-null   float64
#  12  twentyyd           4947 non-null   float64
#  13  tenyd              4947 non-null   float64
#  14  twentyss           4947 non-null   float64
#  15  threecone          4947 non-null   float64
# ...

# %%
df.describe() #veri setinin istatiksel bilgilerini verir
# Out:
#               year   heightfeet  heightinches  heightinchestotal       weight  \
# count  4947.000000  4947.000000   4947.000000        4947.000000  4947.000000
# mean   2007.132201     5.805337      4.371437          74.035476   245.579745
# std       5.029664     0.395981      3.279223           2.614778    45.639366
# min    1999.000000     5.000000      0.000000          65.000000   155.000000
# 25%    2003.000000     6.000000      2.000000          73.000000   208.000000
# 50%    2007.000000     6.000000      4.000000          74.000000   237.000000
# 75%    2012.000000     6.000000      6.000000          76.000000   289.000000
# max    2015.000000     6.000000     11.875000          82.000000   386.000000
#
#               arms        hands      fortyyd     twentyyd        tenyd  \
# count  4947.000000  4947.000000  4947.000000  4947.000000  4947.000000
# mean      7.640243     2.252426     4.610386     0.073734     0.129149
# ...

# %%
# Eksik veri sayısı bulma
df.isnull().sum()
# Out:
# year                    0
# name                    0
# firstname               0
# lastname                0
# position                0
# heightfeet              0
# heightinches            0
# heightinchestotal       0
# weight                  0
# arms                    0
# hands                   0
# fortyyd                 0
# twentyyd                0
# tenyd                   0
# twentyss                0
# threecone               0
# vertical                0
# broad                   0
# bench                   0
# round                   0
# college              1470
# pick                 1791
# pickround               0
# picktotal               0
# wonderlic               0
# nflgrade                0
# dtype: int64

# %%
# Pandas ile Xlsx dosyası okuma
df_xlsx=pd.read_excel("stats.xlsx") #read_excelmetodu

# %%
df_xlsx
# Out:
#   Unnamed: 0         year   heightfeet  heightinches  heightinchestotal  \
# 0      count  4947.000000  4947.000000   4947.000000        4947.000000
# 1       mean  2007.132201     5.805337      4.371437          74.035476
# 2        std     5.029664     0.395981      3.279223           2.614778
# 3        min  1999.000000     5.000000      0.000000          65.000000
# 4        25%  2003.000000     6.000000      2.000000          73.000000
# 5        50%  2007.000000     6.000000      4.000000          74.000000
# 6        75%  2012.000000     6.000000      6.000000          76.000000
# 7        max  2015.000000     6.000000     11.875000          82.000000
#
#         weight         arms        hands      fortyyd     twentyyd  ...  \
# 0  4947.000000  4947.000000  4947.000000  4947.000000  4947.000000  ...
# 1   245.579745     7.640243     2.252426     4.610386     0.073734  ...
# 2    45.639366    13.801035     4.070448     0.974087     0.432330  ...
# ...

# %%
df_xlsx.head()
# Out:
#   Unnamed: 0         year   heightfeet  heightinches  heightinchestotal  \
# 0      count  4947.000000  4947.000000   4947.000000        4947.000000
# 1       mean  2007.132201     5.805337      4.371437          74.035476
# 2        std     5.029664     0.395981      3.279223           2.614778
# 3        min  1999.000000     5.000000      0.000000          65.000000
# 4        25%  2003.000000     6.000000      2.000000          73.000000
#
#         weight         arms        hands      fortyyd     twentyyd  ...  \
# 0  4947.000000  4947.000000  4947.000000  4947.000000  4947.000000  ...
# 1   245.579745     7.640243     2.252426     4.610386     0.073734  ...
# 2    45.639366    13.801035     4.070448     0.974087     0.432330  ...
# 3   155.000000     0.000000     0.000000     0.000000     0.000000  ...
# 4   208.000000     0.000000     0.000000     4.530000     0.000000  ...
#
#       twentyss    threecone     vertical        broad        bench  \
# ...

# %%
import pandas as pd
df=pd.read_csv('combine.csv')

# %%
#veri seti içideki random satırlar
df.sample(10,replace=True) #replace True eklenmeli
# Out:
#       year               name firstname  lastname position  heightfeet  \
# 2783  2006       Chad Jackson      Chad   Jackson       WR           6
# 3821  2002         Tim Carter       Tim    Carter       WR           6
# 2222  2008        Mike Gibson      Mike    Gibson       OG           6
# 3253  2004       Rashad Baker    Rashad     Baker       FS           5
# 2164  2008       Tyvon Branch     Tyvon    Branch       CB           6
# 781   2013       Nico Johnson      Nico   Johnson      OLB           6
# 1970  2009   Juaquin Iglesias   Juaquin  Iglesias       WR           6
# 2089  2009     DeAngelo Smith  DeAngelo     Smith       CB           5
# 3976  2002  Jermaine Phillips  Jermaine  Phillips       FS           6
# 3692  2003        Willie Pile    Willie      Pile       FS           6
#
#       heightinches  heightinchestotal  weight   arms  ...  vertical  broad  \
# 2783           1.0               73.0     213   0.00  ...      38.5    122
# ...

# %%
# veri setinden sütun seçme
df['lastname'] #soyadı sütunuun listele
# Out:
# 0        Abdullah
# 1         Agholor
# 2           Ajayi
# 3       Alexander
# 4          Alford
#           ...
# 4942       Yancey
# 4943        Yeast
# 4944        Young
# 4945      Zellner
# 4946      Zereoue
# Name: lastname, Length: 4947, dtype: object

# %%
# Belirli bir değere göre arama yapma
df[df['lastname']=='Amos'] #name sütununda Kwon isimli kişileri listeler
# Out:
#    year         name firstname lastname position  heightfeet  heightinches  \
# 6  2015  Adrian Amos    Adrian     Amos       FS           6           0.0
#
#    heightinchestotal  weight  arms  ...  vertical  broad  bench  round  \
# 6               72.0     218   0.0  ...      35.5    122      0      0
#
#     college  pick  pickround  picktotal  wonderlic  nflgrade
# 6  Penn St.   NaN          0          0          0       5.5
#
# [1 rows x 26 columns]

# %%
#Kullnıcı girişiyle Data frame den arama yapma
aranan_kisi=input('Aranacak kişinin soyadı nedir?')
df[df['lastname'].str.lower()==aranan_kisi.lower()]
# Out:
# Aranacak kişinin soyadı nedir?amos
#    year         name firstname lastname position  heightfeet  heightinches  \
# 6  2015  Adrian Amos    Adrian     Amos       FS           6           0.0
#
#    heightinchestotal  weight  arms  ...  vertical  broad  bench  round  \
# 6               72.0     218   0.0  ...      35.5    122      0      0
#
#     college  pick  pickround  picktotal  wonderlic  nflgrade
# 6  Penn St.   NaN          0          0          0       5.5
#
# [1 rows x 26 columns]

# %%
len(df) #satır sayısını verir
# Out:
# 4947

# %%
# birden fazla sütun 
df[['lastname','college']]
# Out:
#        lastname            college
# 0      Abdullah           Nebraska
# 1       Agholor                USC
# 2         Ajayi          Boise St.
# 3     Alexander                LSU
# 4        Alford      West Virginia
# ...         ...                ...
# 4942     Yancey      Brigham Young
# 4943      Yeast           Kentucky
# 4944      Young       Kansas State
# 4945    Zellner  Fort Valley State
# 4946    Zereoue      West Virginia
#
# [4947 rows x 2 columns]

# %%
# adı ve soyadıfarklı bir dosyaya kaydet
df_ad_soyad=df[['name','lastname']]
df_ad_soyad.to_excel('ad_soyad.xlsx',index=False)

# %%
#2014 yılı kayıtlarını filtrele
df[df['year']==2014]
# Out:
#      year              name firstname    lastname position  heightfeet  \
# 322  2014  Jared Abbrederis     Jared  Abbrederis       WR           6
# 323  2014     Davante Adams   Davante       Adams       WR           6
# 324  2014      Mo Alexander        Mo   Alexander       SS           6
# 325  2014     Ricardo Allen   Ricardo       Allen       CB           5
# 326  2014        Jace Amaro      Jace       Amaro       TE           6
# ..    ...               ...       ...         ...      ...         ...
# 652  2014  Avery Williamson     Avery  Williamson      ILB           6
# 653  2014     Albert Wilson    Albert      Wilson       WR           5
# 654  2014        Kerry Wynn     Kerry        Wynn       DT           6
# 655  2014      David Yankey     David      Yankey       OG           6
# 656  2014    Jordan Zumwalt    Jordan     Zumwalt      ILB           6
#
#      heightinches  heightinchestotal  weight  arms  ...  vertical  broad  \
# ...

# %%
#2015 yılı ve üstü kayıtlarını filtrele
df[df['year']>=2015]
# Out:
#      year            name firstname   lastname position  heightfeet  \
# 0    2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1    2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2    2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3    2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4    2015    Mario Alford     Mario     Alford       WR           5
# ..    ...             ...       ...        ...      ...         ...
# 317  2015  Jameis Winston    Jameis    Winston       QB           6
# 318  2015      Cam Worthy       Cam     Worthy       WR           6
# 319  2015     Gabe Wright      Gabe     Wright       DT           6
# 320  2015     T.J. Yeldon      T.J.     Yeldon       RB           6
# 321  2015     Zach Zenner      Zach     Zenner       RB           5
#
#      heightinches  heightinchestotal  weight  arms  ...  vertical  broad  \
# 0             9.0               69.0     205   0.0  ...      42.5    130
# ...

# %%
#Pandas serileri
type(df.name) # sütuun ismini doğruda yazabilirsiniz
# Out:
# pandas.core.series.Series

# %%
#Serilerde ilk 10 kayıt
df.name[0:10]
# Out:
# 0           Ameer Abdullah
# 1           Nelson Agholor
# 2                Jay Ajayi
# 3           Kwon Alexander
# 4             Mario Alford
# 5           Javorius Allen
# 6              Adrian Amos
# 7            Dres Anderson
# 8           Henry Anderson
# 9    Rory 'Busta' Anderson
# Name: name, dtype: object

# %%
# Seriler
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
# df['name'] = df.name aynı ifadedir

# %%
# Her bir kategorideki toplam sayı
df.year.value_counts()
# Out:
# year
# 1999    377
# 2014    335
# 2015    322
# 2012    314
# 2011    303
# 2010    290
# 2013    287
# 2009    285
# 2005    285
# 2006    281
# 2004    275
# 2007    271
# 2002    270
# 2008    269
# 2001    266
# 2003    259
# 2000    258
# Name: count, dtype: int64

# %%
df.position.value_counts()
# Out:
# position
# WR     631
# CB     490
# RB     455
# DE     415
# OT     390
# DT     370
# OLB    364
# OG     330
# QB     304
# TE     291
# ILB    225
# FS     211
# SS     184
# OC     132
# FB     102
# C       21
# P       12
# K        9
# NT       9
# LS       2
# Name: count, dtype: int64

# %%
# Data Frame 
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
#İstatistik bilgiler
df['weight'].describe()
# Out:
# count    4947.000000
# mean      245.579745
# std        45.639366
# min       155.000000
# 25%       208.000000
# 50%       237.000000
# 75%       289.000000
# max       386.000000
# Name: weight, dtype: float64

# %%
df['weight'].min() # minumu değer
# Out:
# 155

# %%
df['weight'].max() # maximum değer
# Out:
# 386

# %%
df['weight'].mode() # en çok tekrarlanan
# Out:
# 0    211
# Name: weight, dtype: int64

# %%
df['weight'].mean() # ortalama
# Out:
# 245.57974530018194

# %%
df['weight'].median() # ortalama
# Out:
# 237.0

# %%
# mode bazı durumlarda tuple döndürür 
df['weight'].mode()[0]
# Out:
# 211

# %%
df['weight'].std() # standart sapma
# Out:
# 45.6393660873356

# %%
## eksik verileri tamamlama veya çıkarma işlemleri
df.weight.isnull().sum()
# Out:
# 0

# %%
weight_median = df.weight.median()
df_eksikveri = df.weight.fillna(weight_median) # original data frame ı koru

# %%
#ikinci yöntem
df.weight.fillna(weight_median, inplace = True) # mevcut data frame üzerinde değiştir

# %%
#eksik verilerin oranı
df.pick.isnull().sum() / len(df) * 100
# Out:
# 36.203759854457246

# %%
#iloc veya loc kullanımı
df.iloc[0] # 1. satırı getir
# Out:
# year                           2015
# name                 Ameer Abdullah
# firstname                     Ameer
# lastname                   Abdullah
# position                         RB
# heightfeet                        5
# heightinches                    9.0
# heightinchestotal              69.0
# weight                          205
# arms                            0.0
# hands                           0.0
# fortyyd                         4.6
# twentyyd                        0.0
# tenyd                           0.0
# twentyss                       3.95
# threecone                      6.79
# vertical                       42.5
# broad                           130
# bench                            24
# round                             0
# college                    Nebraska
# pick                            NaN
# pickround                         0
# picktotal                         0
# wonderlic                         0
# nflgrade                        5.9
# ...

# %%
# ilk 10 satırı getir
df.iloc[0:10] #df.iloc[:10]
# Out:
#    year                   name     firstname   lastname position  heightfeet  \
# 0  2015         Ameer Abdullah         Ameer   Abdullah       RB           5
# 1  2015         Nelson Agholor        Nelson    Agholor       WR           6
# 2  2015              Jay Ajayi           Jay      Ajayi       RB           6
# 3  2015         Kwon Alexander          Kwon  Alexander      OLB           6
# 4  2015           Mario Alford         Mario     Alford       WR           5
# 5  2015         Javorius Allen      Javorius      Allen       RB           6
# 6  2015            Adrian Amos        Adrian       Amos       FS           6
# 7  2015          Dres Anderson          Dres   Anderson       WR           6
# 8  2015         Henry Anderson         Henry   Anderson       DE           6
# 9  2015  Rory 'Busta' Anderson  Rory 'Busta'   Anderson       TE           6
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# ...

# %%
#İlk satırdan son satıra kadar 10'ar atlayarak listele
df.iloc[::10]
# Out:
#       year              name firstname  lastname position
# 0     2015    Ameer Abdullah     Ameer  Abdullah       RB
# 10    2015  Stephone Anthony  Stephone   Anthony      ILB
# 20    2015   Michael Bennett   Michael   Bennett       DT
# 30    2015      Da'Ron Brown    Da'Ron     Brown       WR
# 40    2015       Joe Cardona       Joe   Cardona       LS
# ...    ...               ...       ...       ...      ...
# 4900  1999       Chris Terry     Chris     Terry       OT
# 4910  1999         Brian Uhl     Brian       Uhl       OC
# 4920  1999      Alton Weaver     Alton    Weaver       DE
# 4930  1999   Gerald Williams    Gerald  Williams       WR
# 4940  1999         Mark Word      Mark      Word      OLB
#
# [495 rows x 5 columns]

# %%
df.iloc[:5,1:3] # satır ve sütun dilimleme
# Out:
#              name firstname
# 0  Ameer Abdullah     Ameer
# 1  Nelson Agholor    Nelson
# 2       Jay Ajayi       Jay
# 3  Kwon Alexander      Kwon
# 4    Mario Alford     Mario

# %%
df.loc[:5,['name','lastname']] # satır indexleri ve stüun adları
# Out:
#              name   lastname
# 0  Ameer Abdullah   Abdullah
# 1  Nelson Agholor    Agholor
# 2       Jay Ajayi      Ajayi
# 3  Kwon Alexander  Alexander
# 4    Mario Alford     Alford
# 5  Javorius Allen      Allen

# %%
df.name[:5] # belirtile sütundaki ilk 5  satır
# Out:
# 0    Ameer Abdullah
# 1    Nelson Agholor
# 2         Jay Ajayi
# 3    Kwon Alexander
# 4      Mario Alford
# Name: name, dtype: object

# %%
df[['name','lastname']][:5] # belirtien sütunlardaki ilk 5 satır
# Out:
#              name   lastname
# 0  Ameer Abdullah   Abdullah
# 1  Nelson Agholor    Agholor
# 2       Jay Ajayi      Ajayi
# 3  Kwon Alexander  Alexander
# 4    Mario Alford     Alford

# %%
import pandas as pd
df=pd.read_csv('combine.csv')

# %%
df.head(3)
# Out:
#    year            name firstname  lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer  Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson   Agholor       WR           6
# 2  2015       Jay Ajayi       Jay     Ajayi       RB           6
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# 0           9.0               69.0     205   0.0  ...      42.5    130     24
# 1           0.0               72.0     198   0.0  ...       0.0      0     12
# 2           0.0               72.0     221   0.0  ...      39.0    121     19
#
#    round    college  pick  pickround  picktotal  wonderlic  nflgrade
# 0      0   Nebraska   NaN          0          0          0       5.9
# 1      0        USC   NaN          0          0          0       5.6
# 2      0  Boise St.   NaN          0          0          0       6.0
#
# [3 rows x 26 columns]

# %%
#data frame den sütunları düşürme
df.drop('name',axis = 1, inplace = True) #name sütununu çıkar ve dataframe i değiştir

# %%
df.head(3) # name sütunu atılmış oalcak
# Out:
#    year firstname  lastname position  heightfeet  heightinches  \
# 0  2015     Ameer  Abdullah       RB           5           9.0
# 1  2015    Nelson   Agholor       WR           6           0.0
# 2  2015       Jay     Ajayi       RB           6           0.0
#
#    heightinchestotal  weight  arms  hands  ...  vertical  broad  bench  round  \
# 0               69.0     205   0.0    0.0  ...      42.5    130     24      0
# 1               72.0     198   0.0    0.0  ...       0.0      0     12      0
# 2               72.0     221   0.0    0.0  ...      39.0    121     19      0
#
#      college  pick  pickround  picktotal  wonderlic nflgrade
# 0   Nebraska   NaN          0          0          0      5.9
# 1        USC   NaN          0          0          0      5.6
# 2  Boise St.   NaN          0          0          0      6.0
#
# [3 rows x 25 columns]

# %%
#df_drop=df.drop('name',axis=1) name sütunu çıkarır ve yeni veri setine atar
#origina veri seti korunur
